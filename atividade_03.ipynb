# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrokat99-stack/Cusro_IA_2926_CETAM/blob/main/atividade_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time # Biblioteca para simular o tempo passando

# %%
print("--- INICIANDO O ALGORITMO DO BOLO ---")
# Out:
# --- INICIANDO O ALGORITMO DO BOLO ---

# %%
# 1. Variaveis: Separando os ingredientes e ferramentas
temperatura_forno_ = 0
forma_untada = True
tigela = [] # Uma lista vazia para colocar os ingredientes
massa_homogenea = False
tempo_de_forno = 40
palito_limpo = False

# %%
# 2. Entrada/Açoes Simples
