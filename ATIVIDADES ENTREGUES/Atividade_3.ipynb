# %% [markdown]
# #CENTRO DE EDUCAÇÃO TECNOLÓGICA DO AMAZONAS - IBC
# CURSO TÉCNICO EM NÍVEL MÉDIO DE INTELIGÊNCIA ARTIFICIAL.
#
#
# ##Manaus, 23 de Março de 2026
# Aluno: Pedro Alves Magalhaes Filho

# %%
print ("Ola, mundo")
# Out:
# Ola, mundo

# %%
2+3
# Out:
# 5

# %%
50-5*7
# Out:
# 15

# %%
(50-5*6)/2
# Out:
# 10.0

# %%
print(int(8/5)) #divisao com operandos inteiros, retorna resultado inteiro (vs.2.7)
print(8./5) #divisao com pelo menos um operando real, retorna resultado real (vs.2.7)
# Out:
# 1
# 1.6

# %%
5**2 #5 elevado ao quadrado
# Out:
# 25

# %%
59**-2
# Out:
# 0.0002872737719046251

# %%
numero = 59
resultado = bin(numero)
print(resultado)#saida '0b111011'
# Out:
# 0b111011
